# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_accident = pd.read_csv("C:/Users/USSB697670/Desktop/GeorgiaTech/Data Mining & Statistical Learning/Projects/Accident_Information.csv")

# %%
df_vehicle = pd.read_csv("C:/Users/USSB697670/Desktop/GeorgiaTech/Data Mining & Statistical Learning/Projects/Vehicle_Information.csv", encoding='unicode_escape')

# %%
df = pd.merge(df_accident, df_vehicle, on='Accident_Index')

# %%
df_f = df.iloc[:, [0,5,7,8,10,11,25,26,28,29,30,31,32,34,35,38,43,44,45,46]]

# %%
df_f
# Out:
#        Accident_Index Accident_Severity       Date Day_of_Week  \
# 0       200501BS00002            Slight   1/5/2005   Wednesday
# 1       200501BS00003            Slight   1/6/2005    Thursday
# 2       200501BS00004            Slight   1/7/2005      Friday
# 3       200501BS00005            Slight  1/10/2005      Monday
# 4       200501BS00006            Slight  1/11/2005     Tuesday
# ...               ...               ...        ...         ...
# 528781  201091NM01935            Slight  2/23/2010     Tuesday
# 528782  201091NM01935            Slight  2/23/2010     Tuesday
# 528783  201091NM01964           Serious  2/23/2010     Tuesday
# 528784  201091NM01964           Serious  2/23/2010     Tuesday
# 528785  201091NM02142           Serious  2/28/2010      Sunday
#
#                     Junction_Control                      Junction_Detail  \
# 0                Auto traffic signal                           Crossroads
# 1       Data missing or out of range  Not at junction or within 20 metres
# 2       Data missing or out of range  Not at junction or within 20 metres
# 3       Data missing or out of range  Not at junction or within 20 metres
# 4       Data missing or out of range  Not at junction or within 20 metres
# ...                              ...                                  ...
# 528781      Give way or uncontrolled              T or staggered junction
# 528782      Give way or uncontrolled              T or staggered junction
# 528783      Give way or uncontrolled              T or staggered junction
# 528784      Give way or uncontrolled              T or staggered junction
# 528785      Give way or uncontrolled              T or staggered junction
#
#        Road_Surface_Conditions           Road_Type  Speed_limit   Time  \
# 0                          Dry    Dual carriageway           30  17:36
# 1                          Dry  Single carriageway           30   0:15
# 2                          Dry  Single carriageway           30  10:35
# 3                  Wet or damp  Single carriageway           30  21:13
# 4                  Wet or damp  Single carriageway           30  12:40
# ...                        ...                 ...          ...    ...
# 528781            Frost or ice  Single carriageway           30   9:38
# 528782            Frost or ice  Single carriageway           30   9:38
# 528783             Wet or damp  Single carriageway           60  18:25
# 528784             Wet or damp  Single carriageway           60  18:25
# 528785             Wet or damp    Dual carriageway           60  15:45
#
#        Urban_or_Rural_Area     Weather_Conditions  Year_x Age_Band_of_Driver  \
# 0                    Urban     Fine no high winds    2005            36 - 45
# 1                    Urban     Fine no high winds    2005            26 - 35
# 2                    Urban     Fine no high winds    2005            46 - 55
# 3                    Urban     Fine no high winds    2005            46 - 55
# 4                    Urban  Raining no high winds    2005            46 - 55
# ...                    ...                    ...     ...                ...
# 528781               Rural     Fine no high winds    2010            46 - 55
# 528782               Rural     Fine no high winds    2010            46 - 55
# 528783               Rural     Fine no high winds    2010            36 - 45
# 528784               Rural     Fine no high winds    2010            46 - 55
# 528785               Rural  Snowing no high winds    2010            26 - 35
#
#         Age_of_Vehicle  Engine_Capacity_.CC.      make  \
# 0                  3.0                8268.0    DENNIS
# 1                  5.0                8300.0    DENNIS
# 2                  4.0                1769.0    NISSAN
# 3                 10.0                  85.0     HONDA
# 4                  1.0                2976.0      AUDI
# ...                ...                   ...       ...
# 528781             NaN                   NaN   RENAULT
# 528782             NaN                   NaN      FORD
# 528783            11.0                 955.0   TRIUMPH
# 528784             NaN                   NaN      FORD
# 528785            13.0                1389.0  VAUXHALL
#
#                           model Propulsion_Code Sex_of_Driver
# 0                           NaN       Heavy oil          Male
# 1                           NaN       Heavy oil          Male
# 2                ALMERA SE AUTO          Petrol        Female
# 3                           NaN          Petrol          Male
# 4       A4 SPORT CABRIOLET AUTO          Petrol          Male
# ...                         ...             ...           ...
# 528781  KANGOO ML19 PLUS 85 DCI             NaN          Male
# 528782  RANGER 4X4 TURBO DIESEL             NaN          Male
# 528783                SPRINT ST          Petrol          Male
# 528784                FIESTA 35             NaN          Male
# 528785     CORSA BREEZE HI-TORQ          Petrol        Female
#
# [528786 rows x 20 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
df_f.describe()
# Out:
#          Speed_limit         Year_x  Age_of_Vehicle  Engine_Capacity_.CC.
# count  528786.000000  528786.000000   459227.000000         483509.000000
# mean       39.312964    2007.789264        6.382345           2151.774726
# std        14.294410       1.716493        4.468305           2123.511077
# min        10.000000    2005.000000        1.000000              1.000000
# 25%        30.000000    2006.000000        3.000000           1299.000000
# 50%        30.000000    2008.000000        6.000000           1686.000000
# 75%        50.000000    2009.000000        9.000000           1998.000000
# max        70.000000    2010.000000       85.000000          96000.000000

# %%
df_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528786 entries, 0 to 528785
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Accident_Index           528786 non-null  object
#  1   Accident_Severity        528786 non-null  object
#  2   Date                     528786 non-null  object
#  3   Day_of_Week              528786 non-null  object
#  4   Junction_Control         528786 non-null  object
#  5   Junction_Detail          528786 non-null  object
#  6   Road_Surface_Conditions  528786 non-null  object
#  7   Road_Type                528786 non-null  object
#  8   Speed_limit              528786 non-null  int64
#  9   Time                     528784 non-null  object
#  10  Urban_or_Rural_Area      528786 non-null  object
#  11  Weather_Conditions       528786 non-null  object
#  12  Year_x                   528786 non-null  int64
#  13  Age_Band_of_Driver       528786 non-null  object
#  14  Age_of_Vehicle           459227 non-null  float64
#  15  Engine_Capacity_.CC.     483509 non-null  float64
#  16  make                     528786 non-null  object
#  17  model                    453120 non-null  object
#  18  Propulsion_Code          491485 non-null  object
#  19  Sex_of_Driver            528786 non-null  object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 80.7+ MB
